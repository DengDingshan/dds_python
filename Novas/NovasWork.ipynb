# %% [markdown]
# # 使用NOVAS 完成上机作业
#
# ** 邓丁山 201611160103 天体测量学期末作业 **

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#使用NOVAS-完成上机作业" data-toc-modified-id="使用NOVAS-完成上机作业-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>使用NOVAS 完成上机作业</a></span></li><li><span><a href="#Novas-Guidebook" data-toc-modified-id="Novas-Guidebook-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Novas Guidebook</a></span><ul class="toc-item"><li><span><a href="#How-to-use-Novas-to-calculate:-some-Earth-Motivate-Parameters?" data-toc-modified-id="How-to-use-Novas-to-calculate:-some-Earth-Motivate-Parameters?-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>How to use Novas to calculate: some Earth Motivate Parameters?</a></span></li><li><span><a href="#How-it-shows-in-the-guidebook" data-toc-modified-id="How-it-shows-in-the-guidebook-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>How it shows in the guidebook</a></span></li><li><span><a href="#Import-Packs-we-need" data-toc-modified-id="Import-Packs-we-need-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Import Packs we need</a></span></li></ul></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exercise</a></span><ul class="toc-item"><li><span><a href="#Exercise-I" data-toc-modified-id="Exercise-I-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Exercise I</a></span><ul class="toc-item"><li><span><a href="#Lamost——兴隆站" data-toc-modified-id="Lamost——兴隆站-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Lamost——兴隆站</a></span></li><li><span><a href="#日期、时间的输入：" data-toc-modified-id="日期、时间的输入：-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>日期、时间的输入：</a></span></li><li><span><a href="#读取星表" data-toc-modified-id="读取星表-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>读取星表</a></span></li><li><span><a href="#计算恒星的视位置和测站位置" data-toc-modified-id="计算恒星的视位置和测站位置-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>计算恒星的视位置和测站位置</a></span></li><li><span><a href="#the-definition-for-equ2hor" data-toc-modified-id="the-definition-for-equ2hor-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>the definition for equ2hor</a></span></li><li><span><a href="#选取LAMOST可以观测的源" data-toc-modified-id="选取LAMOST可以观测的源-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>选取LAMOST可以观测的源</a></span></li><li><span><a href="#一共有807个可观测源，接下来画图" data-toc-modified-id="一共有807个可观测源，接下来画图-3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span>一共有807个可观测源，接下来画图</a></span></li></ul></li><li><span><a href="#Exercise-II" data-toc-modified-id="Exercise-II-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Exercise II</a></span><ul class="toc-item"><li><span><a href="#计算位置" data-toc-modified-id="计算位置-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>计算位置</a></span></li><li><span><a href="#画图" data-toc-modified-id="画图-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>画图</a></span></li></ul></li><li><span><a href="#Tips" data-toc-modified-id="Tips-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Tips</a></span></li></ul></li><li><span><a href="#Other-Works-With-HUBBLE" data-toc-modified-id="Other-Works-With-HUBBLE-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Other Works With HUBBLE</a></span></li></ul></div>

# %% [markdown]
# # Novas Guidebook
#
# ## How to use Novas to calculate: some Earth Motivate Parameters?
#
# > the Parameters has:
# > 1. 自行 ——> Hippaku
# > * 周年视差
# > * 光线引力弯曲
# > * 周年光行差
# > * 岁差
# > * 章动

# %% [markdown]
# ## How it shows in the guidebook
# * **Proper motion (generalized)**: the three-dimensional space motion of the star, relative to that of the solar system barycenter, between the catalog epoch and the date of interest. Assumed linear and computed from the catalog proper motion components, radial velocity, and parallax. Projected onto the sky, the motion amounts to less than 1 arcsecond per year (usually much less) except for a few nearby stars. [starvectors, proper_motion]
#
# * **Parallax**: the change in our perspective on stars in the solar neighborhood due to the position of the Earth in its orbit. Its magnitude is (distance in parsecs)-1 and, hence, is always less than 1 arcsecond. [bary2obs]
# * **Gravitational light bending**: the apparent deflection of the light path in the gravitational field of the Sun and, to a much lesser extent, the other planets. Although it reaches 1.8 arcsecond at the limb of the Sun, it falls to 0.05 arcsecond 10o from the Sun and amounts to no more than a few milliarcseconds over the hemisphere of the sky opposite the Sun. [grav_def, grav_vec]
# * **Aberration**: the change in the apparent direction of light caused by the observer’s velocity (v) with respect to the solar system barycenter. Independent of distance, it is approximately equal to v/c, expressed as an angle. Therefore, it can reach 21 arcseconds for observers on the surface of the Earth and somewhat more for instruments in orbit. [aberration]
# * **Atmospheric refraction**: the total angular change in the direction of the light path through the Earth’s atmosphere; applies only to an observer on, or near, the surface of the Earth. The direction of refraction is always assumed to be parallel to the local vertical and a function only of zenith distance although these assumptions may not be true in all cases. At optical wavelengths, its magnitude is zero at the zenith, about 1 arcminute at a zenith distance of 45°, and 0.5° at the horizon. Refraction is roughly proportional to the atmospheric pressure at the observer, but it also depends on other atmospheric parameters and the observational wavelength. [equ2hor, refract]

# %% [markdown]
# ## Import Packs we need

# %%
import numpy as np
import pandas as pd

from novas import compat as novas
from novas.compat import eph_manager

import de405

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用skyfield包（注意需要科学上网下载deltat表）

from skyfield.api import load
import skyfield
import datetime

ts = skyfield.api.load.timescale()
# Out:
# [#################################] 100% deltat.preds

# %%
# Example for using Skyfield

t = ts.tdb(jd=2305424.5)
tt = t.utc_datetime()

print(tt)
# Out:
# 1599-12-08 23:59:17.817000+00:00

# %%
## 读取de405.bin

eph_manager.ephem_open('/Users/dengdingshan/anaconda3/lib/python3.6/site-packages/novas_de405/DE405.bin')
# Out:
# (2305424.5, 2525008.5, 405)

# %% [markdown]
# # Exercise
#
# ## Exercise I
# CDS上下载Bright Star Catalogue, 5th Revised Ed.星表，
#
# 利用其所给的恒星的位置，给出2018年６月１日24点（UTC），
#
# 在北京兴隆观测站利用郭守敬望远镜（原LAMOST）所能观测到的亮于7等的恒星的视位置、测站地平坐标，
#
# 要求位置精度在0.1arcsec以下。
#
# *
# 注：星表自行下载；兴隆的地理坐标自行查找；郭守敬望远镜的观测特性自行搜索（视场等参数）；请根据精度要求取舍位置归算过程中的修正项。*

# %% [markdown]
# ### Lamost——兴隆站
#
# LAMOST安放在中国科学院国家天文台兴隆观测站，该站地处燕山主峰南麓，位于河北省兴隆县连营寨（东经7小时50分，北纬40度23分），海拔960米。

# %%
# Xinglong
# 海拔960米，地理坐标为东经117度34.5分，北纬40度23分36秒

Longitude = +(117 + 34.5/60) # degree
Latitude = +(40 + 23.36/60) # degree
Altitude = 960 # m

# %% [markdown]
# ### 日期、时间的输入：
# 2018年６月１日24点（UTC）
#
# * **jd_tt**: 基于tt的儒略日时间
# * **delta_t**: tt - ut1
# * **Alpha**: 兴隆的恒星时

# %%
# date
# delta_t = tt - ut1
jd_tt = novas.julian_date(day=2,hour=0,month=6,year=2018)

t = ts.utc(day=1,hour=(24-8),minute=0,month=6,second=0,year=2018)
jd_tt = t.tt

Time = ts.tt(jd=jd_tt)
delta_t = Time.tt - Time.ut1 # days
delta_t = delta_t*(24*3600) # s

gst = novas.sidereal_time(accuracy=0,delta_t=delta_t,gst_type=1,jd_high=2458271.1674674074,jd_low=0.0,method=1)
Alpha = gst + Longitude*24/360
print(jd_tt)

print(gst)
# Out:
# 2458271.1674674074
# 8.691633775103558

# %% [markdown]
# ### 读取星表
#
# * 读取从cds下载的亮星星表——存储为BS_df
# * 注意到其中有的视差为负数——扔掉视差为负数的源
# * 另外将视差为0的源的视差规定为：0.001（它的最小分度值）

# %%
# Data_read
data_dir = '/Users/dengdingshan/Documents/data/BrightStar/BrightStar.csv'
BS_df = pd.read_csv(data_dir)
BS_df.loc[26]
# Out:
# HR          27.000000
# DEJ2000     46.072200
# RAJ2000      0.172028
# Vmag         5.030000
# pmRA         0.008000
# pmDE         0.000000
# Parallax    -0.002000
# RadVel      -5.000000
# Name: 26, dtype: float64

# %%
len(BS_df)
# Out:
# 9110

# %%
# only Vmag < 7 accepted
# if Plx is 0, we give it 0.001


BS_df_fil = BS_df[BS_df['Parallax'] >= 0]
print(len(BS_df_fil))
BS_df_fil = BS_df_fil[BS_df_fil['Vmag'] < 7]
print(len(BS_df_fil))
BS_df_fil.loc[:,'Format_Parallax'] = BS_df_fil.copy()['Parallax'].replace(0,0.001).values

BS_df_fil = BS_df_fil.reset_index()
# Out:
# 8946
# 8898

# %%
plt.figure(1)
plt.scatter(BS_df_fil['RAJ2000'],BS_df_fil['DEJ2000'],s=3)

plt.xlabel('RAJ2000')
plt.ylabel('DEJ2000')
plt.savefig('BS_Vless7.png',dpi=200)

# %% [markdown]
# ### 计算恒星的视位置和测站位置
#
# 1. 视位置：Apparent Place:
# > **novas.app_star(jd_tt, star, accuracy=0)**
# >
# > Computes the apparent place of a star at 'date', given its catalog
# > mean place, proper motion, parallax, and radial velocity.
# >
# > star - ** CatEntry **:
# > Instance of CatEntry type object containing catalog data for the
# > object in the ICRS.
#
# 2. 测站位置：Topocentric Place:
# > **novas.topo_star(jd_tt, delta_t, star, position, accuracy=0)**
# >
# >Computes the topocentric place of a star at 'date', given its
# >catalog mean place, proper motion, parallax, and radial velocity.
# >
# >star - **CatEntry**
# >
# >position - **OnSurface**:
# >Instance of OnSurface type object specifying the position of the observer.

# %%
# Parameter (OnSurface) for calculate Topo Position
Exercise_I_OnSurface = novas.make_on_surface(height=Altitude,\
                                             latitude=Latitude,\
                                             longitude=Longitude,\
                                             pressure=1010,\
                                             temperature=20)

jd_ut1 = Time.ut1

Epp_x = 0.116068
Epp_y = 0.447863

# %%
## app_star and topo_star

app_ra = []
app_dec = []
topo_dec = []
topo_ra = []

ZD = []
AZ = []
RAR = []
DECR = []
TA = [] # time angle
TA_origin = []

for i in range(len(BS_df_fil)):

    RA = BS_df_fil['RAJ2000'].values[i]
    DEC = BS_df_fil['DEJ2000'].values[i]
    pm_RA = BS_df_fil['pmRA'].values[i]
    pm_DEC = BS_df_fil['pmDE'].values[i]
    plx = BS_df_fil['Format_Parallax'].values[i]
    Vr = BS_df_fil['RadVel'].values[i]
    
    # make CatEntry for each Sar
    # From J2000 to ICRS:
    Star_Cat = novas.make_cat_entry('ExerciseI','HIP',0,RA,DEC,pm_RA,pm_DEC,plx,Vr) 
    Exercise_I_Cat = novas.transform_cat(4,jd_tt,Star_Cat,jd_tt,'n')
    # Give jd_tt and other parameters
    jd_tt = jd_tt
    
    accuracy = 0
    
    # app_star
    Exercise_I_app = novas.app_star(jd_tt,Exercise_I_Cat,accuracy)
    
    app_ra.append(Exercise_I_app[0])
    app_dec.append(Exercise_I_app[1])
    
    # topo_star need delta_t which is not required in app_star
    delta_t = delta_t
    
    RA_topo,DEC_topo = novas.topo_star(jd_tt, delta_t, Exercise_I_Cat, Exercise_I_OnSurface,accuracy)
    
    topo_ra.append(RA_topo); topo_dec.append(DEC_topo)
    
    # Compute Time Angle
    TA_single = (Alpha - RA_topo)%24
    TA_origin.append(TA_single)
    
    if TA_single >= 12:
        TA_single = TA_single - 24
        
    TA.append(TA_single)
    
    # Give the New Parameter hor need
    jd_ut1 = Time.ut1
    
    # Give the horizontal Position (zd,az)
    (zd,az),(rar,decr) = \
              novas.equ2hor(jd_ut1=jd_ut1,\
              delta_t=delta_t,\
              xp=Epp_x ,yp=Epp_y ,\
              location=Exercise_I_OnSurface,\
              ra=RA_topo,dec=DEC_topo,\
              ref_option=1,accuracy=0)
    
    ZD.append(zd);AZ.append(az);RAR.append(rar);DECR.append(decr)
    
    
BS_df_right = pd.DataFrame({'appRA':app_ra,
                           'appDE':app_dec,
                           'topoRA':topo_ra,
                           'topoDE':topo_dec,
                            'TimeAngle':TA,
                            'TA_origin':TA_origin,
                           'zd':ZD,'az':AZ,'rar':RAR,'decr':DECR})
BS_df_new = pd.concat([BS_df_fil,BS_df_right],axis=1)
BS_df_new
# Out:
#       index    HR  DEJ2000   RAJ2000  Vmag   pmRA   pmDE  Parallax  RadVel  \
# 0         0     1  45.2292  0.086083  6.70 -0.012 -0.018     0.000     -18
# 1         1     2  -0.5031  0.084389  6.29  0.045 -0.060     0.000      14
# 2         2     3  -5.7075  0.088917  4.61 -0.009  0.089     0.014      -6
# 3         3     4  13.3961  0.095000  5.51  0.045 -0.012     0.000      -2
# 4         4     5  58.4367  0.104444  5.96  0.263  0.030     0.047     -12
# 5         5     6 -49.0750  0.105278  5.70  0.565 -0.038     0.050       3
# 6         6     7  64.1961  0.107361  5.59  0.008  0.000     0.000       0
# 7         7     8  29.0214  0.110222  6.13  0.380 -0.182     0.067      -8
# 8         8     9 -23.1075  0.113917  6.18  0.100 -0.045     0.000       3
# 9         9    10 -17.3864  0.121722  6.19 -0.018  0.036     0.000      -9
# 10       10    11  -2.5489  0.128917  6.43  0.027 -0.002     0.000      13
# ...

# %% [markdown]
# ### the definition for equ2hor
#  (zd, az) : tuple of floats
#
#      Topocentric (zenith distance, azimuth) in degrees. Zenith
#      distance is affected by refraction if 'ref_option', is
#      non-zero. Azimuth is measured east from north.
#  (rar, decr) : tuple of floats
#
#      Topocentric (right ascension in hours, declination in
#      degrees) of object of interest, referred to true equator and
#      equinox of date, affected by refraction if 'ref_option' is
#      non-zero.

# %%
# Show the Colums
BS_df_new.columns
# Out:
# Index(['index', 'HR', 'DEJ2000', 'RAJ2000', 'Vmag', 'pmRA', 'pmDE', 'Parallax',
#        'RadVel', 'Format_Parallax', 'TA_origin', 'TimeAngle', 'appDE', 'appRA',
#        'az', 'decr', 'rar', 'topoDE', 'topoRA', 'zd'],
#       dtype='object')

# %% [markdown]
# ### 选取LAMOST可以观测的源
#
# 时角正负两小时，赤纬-10度到90度
#
# 此次观测的时间是2018年６月１日24点（UTC）
#
# （* 当地在北点附近正负两小时的源， —— ** 地平经度（azimuth) +- 15degrees**  ）*_ 不对
#
# 时角的角度和地平经度的角度应该不能直接换算？
#
# 以及赤纬-10到90度的源可以观测。 —— ** 赤纬 decr -10，90 degrees **

# %%
Can_observe_fram = BS_df_new[((BS_df_new['TA_origin']<=2)\
                             |(BS_df_new['TA_origin']>=22))\
                           &( (BS_df_new['decr'] >= -10)\
                           &(BS_df_new['decr'] <= 90) )]
len(Can_observe_fram)
# Out:
# 732

# %% [markdown]
# ### 一共有807个可观测源，接下来画图

# %%
# draw x is for az, y is for decr
plt.figure(2)

xx = 'TimeAngle'
yy = 'decr'

plt.scatter(BS_df_new[xx],BS_df_new[yy],c='lightgrey',s=3,alpha=0.5)
plt.scatter(Can_observe_fram[xx],Can_observe_fram[yy],c = 'b',s = 5)

plt.xlabel(xx+' $_{Hours}$')
plt.ylabel(yy+' $_{Degrees}$')

plt.savefig('NovasTA_DECR.png',dpi=200)
plt.show()

# %% [markdown]
# ## Exercise II
#
# 计算2018年６月１日24点（UTC），
#
# 月球、金星、火星、木星和土星的站心位置、地平坐标，要求位置精度在0.1arcsec以下。
#
# 请结合第一个实验中得到的恒星位置，说明此时的月球、金星、火星、木星和土星是否会影响恒星的观测。
#
# *
# 注：请根据精度要求取舍位置归算过程中的修正项。*

# %% [markdown]
# ### 计算位置
#
# 需要用到的新函数：topo_planet

# %%
# novas.topo_planet(jd_tt, delta_t, ss_body, position, accuracy=0)

# ss_body = Object type
# Position = Onsurface

# (ra, dec, dis) : tuple of floats
#     Topocentric (right ascension in hours, declination in
#     degrees, ...), referred to true equator and equinox of date,
#     and true (..., ..., distance in AU) from Earth to solar
#     system body at 'jd_tt'.

# novas.make_object

# %%
# Give Parameters (Same as the Exercise I)
jd_tt = jd_tt
delta_t = delta_t

Exercise_II_OnSurface = novas.make_on_surface(height=Altitude,\
                                             latitude=Latitude,\
                                             longitude=Longitude,\
                                             pressure=1010,\
                                             temperature=20)

jd_ut1 = Time.ut1
Epp_x = 0.116068
Epp_y = 0.447863

Alpha = Alpha

# %%
# number : integer
# For 'type' = 0: Mercury = 1, ..., Pluto = 9, Sun = 10, Moon = 11
# Moon, Venus, Mars, Jupyter, Saturn
Number = [11,2,4,5,6,10]
Name = ['Moon','Venus','Mars','Jupyter','Saturn','Sun']

Topo_p = []
Obs_p = []
TA_p = []
TA_op = []

for i in range(len(Number)):
    
    Object_this = novas.make_object(type=0,number=Number[i],name=Name[i],star_data=None)
    Topo_this = novas.topo_planet(accuracy=0,delta_t=delta_t,jd_tt=jd_tt,\
                                  position=Exercise_II_OnSurface,ss_body=Object_this)
    Topo_p.append(Topo_this)
    
    (zd,az),(rar,decr) = \
              novas.equ2hor(jd_ut1=jd_ut1,\
              delta_t=delta_t,\
              xp=Epp_x ,yp=Epp_y ,\
              location=Exercise_II_OnSurface,\
              ra=Topo_this[0],dec=Topo_this[1],\
              ref_option=1,accuracy=0)
    Obs_p.append([zd,az,rar,decr])
    
    TA_single = (Alpha - rar)%24
    TA_op.append(TA_single)
    
    if TA_single >= 12:
        TA_single = TA_single - 24
        
    TA_p.append(TA_single)
    
Topo_planet_fram = pd.DataFrame(data=np.array(Topo_p),columns=['ra','dec','dis'])
Topo_planet_fram['Name'] = Name

Observe_planet_fram = pd.DataFrame(data=np.array(Obs_p),columns=['zd','az','rar','decr'])

Planet_df = pd.concat([Topo_planet_fram,Observe_planet_fram],axis=1)

Planet_df['TimeAngle'] = np.array(TA_p)
Planet_df['TA_origin'] = np.array(TA_op)

# %% [markdown]
# ### 画图

# %%
Planet_df['TimeAngle'][0]
# Out:
# -2.582425723594053

# %%
plt.figure(2)

xx = 'rar'
yy = 'decr'

plt.scatter(BS_df_new[xx],BS_df_new[yy],c='lightgrey',s=3,alpha=0.5)
plt.scatter(Can_observe_fram[xx],Can_observe_fram[yy],c = 'b',s = 5)
plt.scatter(Planet_df[xx],Planet_df[yy],c = 'r',s = 10)

plt.xlabel('RA$_{topo Hours}$')
plt.ylabel('DEC$_{topo Degrees}$')

plt.savefig('RADECwithPlanets.png',dpi=200)

# %%
plt.figure(3)

xx = 'TimeAngle'
yy = 'decr'

plt.scatter(BS_df_new[xx],BS_df_new[yy],c='lightgrey',s=3,alpha=0.5,label='BrightStar')
plt.scatter(Can_observe_fram[xx],Can_observe_fram[yy],c = 'b',s = 3,label='Can be Observed')
plt.scatter(Planet_df[xx][0],Planet_df[yy][0],c = 'orange',s = 20,label='Moon')
plt.scatter(Planet_df[xx][5],Planet_df[yy][5],c = 'Red',s = 30,label='Sun')
plt.scatter(Planet_df[xx][1:5],Planet_df[yy][1:5],c='purple',s = 10,label='Planet')

plt.xlabel('TimeAngle$ _{Hours}$')
plt.ylabel('DEC$_{topo Degrees}$')
plt.legend()

plt.savefig('RADECwithPlanets.png',dpi=200)

# %%
plt.figure(3)

xx = 'az'
yy = 'zd'

plt.scatter(BS_df_new[xx],BS_df_new[yy],c='lightgrey',s=3,alpha=0.5,label='BrightStar')
plt.scatter(Can_observe_fram[xx],Can_observe_fram[yy],c = 'b',s = 3,label='Can be Observed')
plt.scatter(Planet_df[xx][0],Planet_df[yy][0],c = 'orange',s = 20,label='Moon')
plt.scatter(Planet_df[xx][5],Planet_df[yy][5],c = 'Red',s = 30,label='Sun')
plt.scatter(Planet_df[xx][1:5],Planet_df[yy][1:5],c='purple',s = 10,label='Planet')

plt.xlabel('azimuth$ _{Degrees}$')
plt.ylabel('zenith distance$_{Degrees}$')
plt.legend()

plt.savefig('AZZDwithPlanets.png',dpi=200)

# %% [markdown]
# ## Tips
#
# 程序中涉及到的时间转化，请同步完成。由于只计算一个时刻的位置，可以简化相关数据文件读取过程。
#
# *
# 注：相关数据文件请到IERS网站查找。*

# %%
Can_observe_fram.to_csv('Can_be_observed.csv')

# %%
Can_observe_fram.columns
# Out:
# Index(['index', 'HR', 'DEJ2000', 'RAJ2000', 'Vmag', 'pmRA', 'pmDE', 'Parallax',
#        'RadVel', 'Format_Parallax', 'TA_origin', 'TimeAngle', 'appDE', 'appRA',
#        'az', 'decr', 'rar', 'topoDE', 'topoRA', 'zd'],
#       dtype='object')

# %% [markdown]
# # Other Works With HUBBLE

# %%
BS_df_fil
# Out:
#       index    HR  DEJ2000   RAJ2000  Vmag   pmRA   pmDE  Parallax  RadVel  \
# 0         0     1  45.2292  0.086083  6.70 -0.012 -0.018     0.000     -18
# 1         1     2  -0.5031  0.084389  6.29  0.045 -0.060     0.000      14
# 2         2     3  -5.7075  0.088917  4.61 -0.009  0.089     0.014      -6
# 3         3     4  13.3961  0.095000  5.51  0.045 -0.012     0.000      -2
# 4         4     5  58.4367  0.104444  5.96  0.263  0.030     0.047     -12
# 5         5     6 -49.0750  0.105278  5.70  0.565 -0.038     0.050       3
# 6         6     7  64.1961  0.107361  5.59  0.008  0.000     0.000       0
# 7         7     8  29.0214  0.110222  6.13  0.380 -0.182     0.067      -8
# 8         8     9 -23.1075  0.113917  6.18  0.100 -0.045     0.000       3
# 9         9    10 -17.3864  0.121722  6.19 -0.018  0.036     0.000      -9
# 10       10    11  -2.5489  0.128917  6.43  0.027 -0.002     0.000      13
# ...

# %%
plt.figure(1)
plt.scatter(BS_df['RAJ2000'],BS_df['DEJ2000'],s=3)

plt.xlabel('RAJ2000')
plt.ylabel('DEJ2000')
# Out:
# Text(0,0.5,'DEJ2000')

# %%
center = [9,-50]

# %%
Lamost_5 = BS_df[(abs(BS_df['DEJ2000']-center[1])<5)\
                    &(abs(BS_df['RAJ2000']-center[0])<5/360*24)]
len(Lamost_5)
# Out:
# 37

# %%
len(Lamost_5[(Lamost_5['Vmag']<7)])
# Out:
# 37

# %%
Hubble = Lamost_5 = BS_df[(abs(BS_df['DEJ2000']-center[1])<(123/2)/3600)\
                         &(abs(BS_df['RAJ2000']-center[0])<(137/2)/3600/360*24)]

# %%
len(Hubble)
# Out:
# 0
